# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model,preprocessing
from sklearn.utils import shuffle
import numpy as np

# %%
df=pd.read_csv(r"E:\E3\eunimart\898ce544-0-MLChallenge_1Datac63af4e\train_indessa.csv")

# %%
print(df.columns[22])
df[df.columns[36]].head()
# Out:
# inq_last_6mths
# 0    74.0
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# Name: mths_since_last_major_derog, dtype: float64

# %%
df.keys()
df.columns[14]
# Out:
# 'pymnt_plan'

# %%
df.corr()
# Out:
#                              member_id  loan_amnt  funded_amnt  \
# member_id                     1.000000   0.065607     0.067888
# loan_amnt                     0.065607   1.000000     0.999276
# funded_amnt                   0.067888   0.999276     1.000000
# funded_amnt_inv               0.073426   0.997124     0.998041
# int_rate                     -0.141030   0.145037     0.145222
# annual_inc                    0.034649   0.330655     0.330493
# dti                           0.134179   0.041866     0.042699
# delinq_2yrs                   0.049956  -0.000454    -0.000171
# inq_last_6mths               -0.127644  -0.033693    -0.034298
# mths_since_last_delinq       -0.008538  -0.038069    -0.038058
# mths_since_last_record       -0.161942  -0.012130    -0.012119
# open_acc                      0.087966   0.197630     0.198078
# pub_rec                       0.080268  -0.080952    -0.080613
# revol_bal                     0.035607   0.333944     0.333785
# ...

# %%
l=preprocessing.LabelEncoder()
df["term"]=l.fit_transform(list(df["term"]))
df["grade"]=l.fit_transform(list(df["grade"]))
df["sub_grade"]=l.fit_transform(list(df["sub_grade"]))
df["application_type"]=l.fit_transform(list(df["application_type"]))
df["home_ownership"]=l.fit_transform(list(df["home_ownership"]))
df["verification_status"]=l.fit_transform(list(df["verification_status"]))
df["purpose"]=l.fit_transform(list(df["purpose"]))
df["title"]=l.fit_transform(list(df["title"]))
#df["loan_status"]=l.fit_transform(df["loan_status"])

# %%
df["initial_list_status"]=l.fit_transform(list(df["initial_list_status"]))

# %%
df["last_week_pay"]=l.fit_transform(list(df["last_week_pay"]))

# %%
for col in df.columns:
    print("Col :",col, "\t\tNull Values count: ",df[col].isnull().sum(),"\t\tUnique values count: ",len(df[col].unique()))
# Out:
# Col : member_id 		Null Values count:  0 		Unique values count:  532428
# Col : loan_amnt 		Null Values count:  0 		Unique values count:  1370
# Col : funded_amnt 		Null Values count:  0 		Unique values count:  1370
# Col : funded_amnt_inv 		Null Values count:  0 		Unique values count:  6442
# Col : term 		Null Values count:  0 		Unique values count:  2
# Col : batch_enrolled 		Null Values count:  85149 		Unique values count:  105
# Col : int_rate 		Null Values count:  0 		Unique values count:  535
# Col : grade 		Null Values count:  0 		Unique values count:  7
# Col : sub_grade 		Null Values count:  0 		Unique values count:  35
# Col : emp_title 		Null Values count:  30833 		Unique values count:  190125
# Col : emp_length 		Null Values count:  26891 		Unique values count:  12
# Col : home_ownership 		Null Values count:  0 		Unique values count:  6
# Col : annual_inc 		Null Values count:  3 		Unique values count:  33989
# ...

# %%
pred='loan_status'
x=list(zip(df["loan_amnt"],df["funded_amnt"],df["funded_amnt_inv"],df["int_rate"],df["sub_grade"],df["home_ownership"],df["revol_bal"],df["application_type"],df["term"],df["grade"],df["verification_status"],df["purpose"],df["last_week_pay"],df["total_rec_int"],df["title"]))
#x=list(zip([df["loan_amnt"]],[df["funded_amnt"]]))
y=list(zip(df["loan_status"]))

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(x,y,test_size=0.5)

# %%
from sklearn import linear_model
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB,CategoricalNB,ComplementNB
from sklearn import tree
from sklearn.ensemble import BaggingClassifier,HistGradientBoostingClassifier,GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,AdaBoostClassifier
#reg=tree.DecisionTreeClassifier(max_depth=7)   #82%acc
reg=RandomForestClassifier(criterion='entropy')   #85.40422%acc
#reg=RandomForestClassifier()    #85.30280%acc
reg.fit(x_train,y_train)
# Out:
# <ipython-input-21-7764e29c8ee5>:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg.fit(x_train,y_train)
# RandomForestClassifier(criterion='entropy')

# %%
reg.score(x_test,y_test)
# Out:
# 0.8536327916638494

# %% [markdown]
# ## Testing

# %%
dft=pd.read_csv(r"E:\E3\eunimart\898ce544-0-MLChallenge_1Datac63af4e\test_indessa.csv")

# %%
l=preprocessing.LabelEncoder()
dft["term"]=l.fit_transform(list(dft["term"]))
dft["grade"]=l.fit_transform(list(dft["grade"]))
dft["sub_grade"]=l.fit_transform(list(dft["sub_grade"]))
dft["application_type"]=l.fit_transform(list(dft["application_type"]))
dft["home_ownership"]=l.fit_transform(list(dft["home_ownership"]))
dft["verification_status"]=l.fit_transform(list(dft["verification_status"]))
dft["purpose"]=l.fit_transform(list(dft["purpose"]))
dft["title"]=l.fit_transform(list(dft["title"]))
dft["initial_list_status"]=l.fit_transform(list(dft["initial_list_status"]))
dft["last_week_pay"]=l.fit_transform(list(dft["last_week_pay"]))

# %%
x=list(zip(dft["loan_amnt"],dft["funded_amnt"],dft["funded_amnt_inv"],dft["int_rate"],dft["sub_grade"],dft["home_ownership"],dft["revol_bal"],dft["application_type"],dft["term"],dft["grade"],dft["verification_status"],dft["purpose"],dft["last_week_pay"],dft["total_rec_int"],dft["title"]))

# %%
result=reg.predict(x)

# %%
final=pd.Series(result)

# %%
df_result=pd.DataFrame(final)

# %%
df_result.to_csv('test_result.csv',index=False)
